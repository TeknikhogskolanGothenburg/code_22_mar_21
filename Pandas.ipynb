# %%
import pandas as pd

df = pd.read_csv('Sales_April_2019.csv')

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
df.isna().sum()
# Out:
# Order ID            59
# Product             59
# Quantity Ordered    59
# Price Each          59
# Order Date          59
# Purchase Address    59
# dtype: int64

# %%
nans = df[df.isna().any(axis=1)]

# %%
nans.head(59)
# Out:
#       Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 1          NaN     NaN              NaN        NaN        NaN              NaN
# 356        NaN     NaN              NaN        NaN        NaN              NaN
# 735        NaN     NaN              NaN        NaN        NaN              NaN
# 1433       NaN     NaN              NaN        NaN        NaN              NaN
# 1553       NaN     NaN              NaN        NaN        NaN              NaN
# 1571       NaN     NaN              NaN        NaN        NaN              NaN
# 1992       NaN     NaN              NaN        NaN        NaN              NaN
# 2265       NaN     NaN              NaN        NaN        NaN              NaN
# 2798       NaN     NaN              NaN        NaN        NaN              NaN
# 3024       NaN     NaN              NaN        NaN        NaN              NaN
# 3098       NaN     NaN              NaN        NaN        NaN              NaN
# ...

# %%
df = df.dropna()
df.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
df.loc[500:520]
# Out:
#      Order ID                     Product  Quantity Ordered  Price Each  \
# 500    177036    Lightning Charging Cable                 2       14.95
# 501    177037      34in Ultrawide Monitor                 1      379.99
# 502    177038                      iPhone                 1         700
# 503    177039      AAA Batteries (4-pack)                 1        2.99
# 504    177040        USB-C Charging Cable                 1       11.95
# 505    177041            Wired Headphones                 1       11.99
# 506    177042    Lightning Charging Cable                 1       14.95
# 507    177043      27in 4K Gaming Monitor                 1      389.99
# 508    177044       AA Batteries (4-pack)                 1        3.84
# 509    177045               Flatscreen TV                 1         300
# 510    177046             Vareebadd Phone                 1         400
# 511    177047    Lightning Charging Cable                 1       14.95
# ...

# %%
df = df[['Order ID', 'Quantity Ordered', 'Price Each']].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Order ID"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-c4bbb003b36a> in <module>
# ----> 1 df = df[['Order ID', 'Quantity Ordered', 'Price Each']].apply(pd.to_numeric)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# ...

# %%
df = df[df['Order ID'].str[0:2] != 'Or']

# %%
df = df[['Order ID', 'Quantity Ordered', 'Price Each']].apply(pd.to_numeric)

# %%
df.dtypes
# Out:
# Order ID              int64
# Product              object
# Quantity Ordered      int64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# dtype: object

# %%
df['Order ID'] = pd.to_numeric(df['Order ID'])

# %%
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'])

# %%
df['Price Each'] = pd.to_numeric(df['Price Each'])
